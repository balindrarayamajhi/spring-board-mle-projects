# %%
import kagglehub
import pandas as pd
from pathlib import Path

# %%
path = kagglehub.dataset_download("uttamp/store-data")

path
# Out:
# '/Users/balindrarayamajhi/.cache/kagglehub/datasets/uttamp/store-data/versions/1'

# %%
data_dir = Path(path)
data_dir
# Out:
# PosixPath('/Users/balindrarayamajhi/.cache/kagglehub/datasets/uttamp/store-data/versions/1')

# %%
excel_files = list(data_dir.glob("*.xlsx")) + list(data_dir.glob("*.xls"))
excel_files
# Out:
# [PosixPath('/Users/balindrarayamajhi/.cache/kagglehub/datasets/uttamp/store-data/versions/1/storedata_total.xlsx')]

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module="openpyxl")
df = pd.read_excel(excel_files[0])
df.head()
# Out:
#    custid  retained    created           firstorder            lastorder  \
# 0  6H6T6N         0 2012-09-28  2013-08-11 00:00:00  2013-08-11 00:00:00
# 1  APCENR         1 2010-12-19  2011-04-01 00:00:00  2014-01-19 00:00:00
# 2  7UP6MS         0 2010-10-03  2010-12-01 00:00:00  2011-07-06 00:00:00
# 3  7ZEW8G         0 2010-10-22  2011-03-28 00:00:00  2011-03-28 00:00:00
# 4  8V726M         1 2010-11-27  2010-11-29 00:00:00  2013-01-28 00:00:00
#
#    esent   eopenrate  eclickrate  avgorder   ordfreq  paperless  refill  \
# 0     29  100.000000    3.448276     14.52  0.000000          0       0
# 1     95   92.631579   10.526316     83.69  0.181641          1       1
# 2      0    0.000000    0.000000     33.58  0.059908          0       0
# 3      0    0.000000    0.000000     54.96  0.000000          0       0
# 4     30   90.000000   13.333333    111.91  0.008850          0       0
#
#    doorstep     favday city
# 0         0     Monday  DEL
# 1         1     Friday  DEL
# 2         0  Wednesday  DEL
# 3         0   Thursday  BOM
# 4         0     Monday  BOM

# %%
df.to_csv("storedata.csv", index=False)

df = pd.read_csv("storedata.csv")
df.head()
# Out:
#    custid  retained     created           firstorder            lastorder  \
# 0  6H6T6N         0  2012-09-28  2013-08-11 00:00:00  2013-08-11 00:00:00
# 1  APCENR         1  2010-12-19  2011-04-01 00:00:00  2014-01-19 00:00:00
# 2  7UP6MS         0  2010-10-03  2010-12-01 00:00:00  2011-07-06 00:00:00
# 3  7ZEW8G         0  2010-10-22  2011-03-28 00:00:00  2011-03-28 00:00:00
# 4  8V726M         1  2010-11-27  2010-11-29 00:00:00  2013-01-28 00:00:00
#
#    esent   eopenrate  eclickrate  avgorder   ordfreq  paperless  refill  \
# 0     29  100.000000    3.448276     14.52  0.000000          0       0
# 1     95   92.631579   10.526316     83.69  0.181641          1       1
# 2      0    0.000000    0.000000     33.58  0.059908          0       0
# 3      0    0.000000    0.000000     54.96  0.000000          0       0
# 4     30   90.000000   13.333333    111.91  0.008850          0       0
#
#    doorstep     favday city
# 0         0     Monday  DEL
# 1         1     Friday  DEL
# 2         0  Wednesday  DEL
# 3         0   Thursday  BOM
# 4         0     Monday  BOM

# %%
df.shape
# Out:
# (30801, 15)

# %%
df.isna().sum()
# Out:
# custid        20
# retained       0
# created       20
# firstorder    20
# lastorder     20
# esent          0
# eopenrate      0
# eclickrate     0
# avgorder       0
# ordfreq        0
# paperless      0
# refill         0
# doorstep       0
# favday         0
# city           0
# dtype: int64
