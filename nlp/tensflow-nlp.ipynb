# %%
from tensorflow.keras.preprocessing.text import Tokenizer

sentences = [
    'i love my dog',
    'I, love my cat',
    'You love my dog!',
    'Do you think my dog is amazing?'
]

tokenizer = Tokenizer(num_words = 100)
tokenizer.fit_on_texts(sentences)

# %%
word_index = tokenizer.word_index
word_index
# Out:
# {'love': 1, 'my': 2, 'i': 3, 'dog': 4, 'cat': 5, 'you': 6}

# %%
sequence = tokenizer.texts_to_sequences(sentences)
sequence
# Out:
# [[4, 2, 1, 3], [4, 2, 1, 6], [5, 2, 1, 3], [7, 5, 8, 1, 3, 9, 10]]

# %%
test_sentences = [
    'I really love my dog',
    'My dog loves my manatee', ]
test_sequence = tokenizer.texts_to_sequences(test_sentences)
test_sequence
# Out:
# [[4, 2, 1, 3], [1, 3, 1]]

# %%
out_of_vocab_tokenizer = Tokenizer(num_words = 100, oov_token= '<OOV>')
out_of_vocab_tokenizer.fit_on_texts(sentences)
word_index = out_of_vocab_tokenizer.word_index
word_index
# Out:
# {'<OOV>': 1,
#  'my': 2,
#  'love': 3,
#  'dog': 4,
#  'i': 5,
#  'you': 6,
#  'cat': 7,
#  'do': 8,
#  'think': 9,
#  'is': 10,
#  'amazing': 11}

# %%
oov_test_sequence = out_of_vocab_tokenizer.texts_to_sequences([
    'I really love my dog',
    'My dog loves my manatee', ])
oov_test_sequence
# Out:
# [[5, 1, 3, 2, 4], [2, 4, 1, 2, 1]]

# %%
out_of_vocab_tokenizer.word_index
# Out:
# {'<OOV>': 1,
#  'my': 2,
#  'love': 3,
#  'dog': 4,
#  'i': 5,
#  'you': 6,
#  'cat': 7,
#  'do': 8,
#  'think': 9,
#  'is': 10,
#  'amazing': 11}
